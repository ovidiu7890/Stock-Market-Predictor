# %%
# !pip install yfinance pandas numpy scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 5.6 MB/s eta 0:00:00
# ...
#
#    ----------------------------------------  0/11 [pytz]
#    ----------------------------------------  0/11 [pytz]
#    ----------------------------------------  0/11 [pytz]
#    --- ------------------------------------  1/11 [peewee]
#    --- ------------------------------------  1/11 [peewee]
#    ---------- -----------------------------  3/11 [websockets]
#    ---------- -----------------------------  3/11 [websockets]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    --------------------- ------------------  6/11 [frozendict]
#    ------------------------- --------------  7/11 [markdown-it-py]
# ...
